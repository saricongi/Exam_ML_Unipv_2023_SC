# %% [markdown]
# <a href="https://colab.research.google.com/github/saricongi/Exam_ML_Unipv_2023_SC/blob/master/1D_CNN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.sparse import load_npz
import h5py

# %%
# directory = 'https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git'
# !git clone https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git
# !curl https://github.com/saricongiExam_ML_Unipv_2023_SC.git
# Out:
# Cloning into 'Exam_ML_Unipv_2023_SC'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 36 (delta 3), reused 0 (delta 0), pack-reused 27
# Receiving objects: 100% (36/36), 48.57 MiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (8/8), done.
# Not Found

# %% [markdown]
# The dataset is made by transmission optical spectra of optical resonators integrated on a silicon chip as the one shown here:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/device.png?raw=1" width="800"/>
# </div>
#
# A typical mesured spectrum can have a shape as the following:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/Example.png?raw=1" width="600"/>
# </div>
#
# The analysis of this type of spectra with theoretical models is not straightforward, because one single resonance is given by the contribution of both ring resonators, with interference occuring between the two. For application in light storing and optical switchers, we are interested on the devices and wavelength ranges where double peaks occurs.
#
# The goal of this ML project is to correctly recognize if a resonance is showing the  single-peak or the double-peak behaviour. Therefore, each spectrum has a label *z* to classify it into the two possible groups (*binary classification problem*).
#
# Since it is a periodic pattern, the full wavelength (*wl*) scan has been splitted in different arrays of equal length (*300*), each of them contains a single resonance. In this way, more than 6000 resonance spectra have been recorded, divided in *train* and *test* datasets.
#
# Moreover, the information on the absolute wl is not of our interest, thus we are going to normalize it (*x* between 0 and 1). Since independetly on the resonance position we want to be able to classify the peaks, our problem exibits *translational symmetry*. For this reason, the model implemented is a **1D CNN**.
#
#
# **DATASETs STRUCTURE:**
#
# * **Train dataset = 3532 spectra**
# * **Test (or evaluation) dataset = 3569 spectra**
# * **1 spectrum = 300 wavelength points -> y**.
# * **Nb labels = 2 -> z**, *z=0* if there is only one visible peak, *z=1* if the resonance is splittend into 2 peaks.

# %% [markdown]
# ## **Train Dataset:**

# %%
## Train DataSet
url = '/content/Exam_ML_Unipv_2023_SC/DataSet_train2.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=0
j=24
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=2
j=30
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=3
j=35
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <ipython-input-3-99efe4a0af77>:35: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-99efe4a0af77>:36: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:45: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:46: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:47: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:69: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-99efe4a0af77>:70: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:71: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:76: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:77: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:78: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:100: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-99efe4a0af77>:101: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:102: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-99efe4a0af77>:107: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:108: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-99efe4a0af77>:109: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))

# %% [markdown]
# ### **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(0,NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytrain = []
xtrain = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytrain = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytrain.append(my_ytrain)
      target.append(my_target)
      xtrain.append(x)

ytrain=np.array(ytrain).reshape(-1,300,1)
ztrain=np.array(target).reshape(-1,1)
xtrain=np.array(xtrain).reshape(-1,300,1)

print("xtrain shape: ", xtrain.shape)
print("ytrain shape: ", ytrain.shape)
print("ztrain shape: ", ztrain.shape)

hf.close()
# Out:
# <ipython-input-4-5c7621e0802b>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytrain = np.array(sg.get('y'+str(k)))
# <ipython-input-4-5c7621e0802b>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# xtrain shape:  (3532, 300, 1)
# ytrain shape:  (3532, 300, 1)
# ztrain shape:  (3532, 1)

# %% [markdown]
# ### Let's check that in the train dataset there the two labels are well distributed:

# %%
plt.hist(ztrain, len(ztrain[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Train Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztrain[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **1D CNN MODEL**

# %%
# keras imports
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Conv1D, AveragePooling1D, Dropout, Flatten
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN

# %%
featureArrayLength = (ytrain.shape[1],ytrain.shape[2])
dropoutRate = 0.25

batch_size = 128
n_epochs = 50
n_neurons = 1024

# CNN 1D
####
inputList = Input(shape=(featureArrayLength))
x = Conv1D(20, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(inputList)
x = AveragePooling1D(pool_size=2)(x)
# #
x = Conv1D(40, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=4)(x)
# #
x = Conv1D(60, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=8)(x)

# (inputList)
x = Flatten()(x)
x = Dense(n_neurons, activation='relu')(x)
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)
####
model = Model(inputs=inputList, outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 1)]          0
#
#  conv1d (Conv1D)             (None, 298, 20)           80
#
#  average_pooling1d (AverageP  (None, 149, 20)          0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 147, 40)           2440
#
#  average_pooling1d_1 (Averag  (None, 36, 40)           0
#  ePooling1D)
#
#  conv1d_2 (Conv1D)           (None, 34, 60)            7260
#
#  average_pooling1d_2 (Averag  (None, 4, 60)            0
#  ePooling1D)
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 1024)              246784
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 257,589
# Trainable params: 257,589
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Test Dataset**

# %%
## Test DataSet

url = '/content/Exam_ML_Unipv_2023_SC/DataSet_test2.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=4
j=26
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=2
ResNb2=21

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=6
j=32
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=7
j=40
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x2": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x43', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y43', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z43', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <ipython-input-9-c2f25d0efd63>:36: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-c2f25d0efd63>:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:38: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:46: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:47: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:48: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:70: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-c2f25d0efd63>:71: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:72: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:77: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:78: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:79: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:101: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-c2f25d0efd63>:102: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:103: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-c2f25d0efd63>:108: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:109: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-c2f25d0efd63>:110: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))

# %% [markdown]
# ## **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(4,4+NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytest = []
xtest = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytest = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytest.append(my_ytest)
      target.append(my_target)
      xtest.append(x)

ytest=np.array(ytest).reshape(-1,300,1)
ztest=np.array(target).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,300,1)
print(ztest.shape, ytest.shape, xtest.shape)

# ztest = to_categorical(target, num_classes = 2)
# print("New dimension of test target:")
# print(ztest.shape)

# hf.close()

plt.hist(ztest, len(ztest[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Test Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztest[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# <ipython-input-10-5479f8c08cf5>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytest = np.array(sg.get('y'+str(k)))
# <ipython-input-10-5479f8c08cf5>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# (3569, 1) (3569, 300, 1) (3569, 300, 1)
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **TRAIN**

# %%
# train
history = model.fit( ytrain, ztrain, epochs=n_epochs, batch_size=batch_size, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/50
# 28/28 - 6s - loss: 0.6579 - accuracy: 0.6433 - val_loss: 0.6818 - val_accuracy: 0.5993 - lr: 0.0010 - 6s/epoch - 210ms/step
# Epoch 2/50
# 28/28 - 2s - loss: 0.6480 - accuracy: 0.6433 - val_loss: 0.6646 - val_accuracy: 0.5993 - lr: 0.0010 - 2s/epoch - 60ms/step
# Epoch 3/50
# 28/28 - 2s - loss: 0.6190 - accuracy: 0.6433 - val_loss: 0.6067 - val_accuracy: 0.6063 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 4/50
# 28/28 - 2s - loss: 0.5362 - accuracy: 0.7305 - val_loss: 0.5069 - val_accuracy: 0.7680 - lr: 0.0010 - 2s/epoch - 63ms/step
# Epoch 5/50
# 28/28 - 2s - loss: 0.4491 - accuracy: 0.8163 - val_loss: 0.4635 - val_accuracy: 0.8148 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 6/50
# 28/28 - 2s - loss: 0.4134 - accuracy: 0.8468 - val_loss: 0.4852 - val_accuracy: 0.7985 - lr: 0.0010 - 2s/epoch - 70ms/step
# Epoch 7/50
# 28/28 - 3s - loss: 0.3995 - accuracy: 0.8638 - val_loss: 0.4414 - val_accuracy: 0.8375 - lr: 0.0010 - 3s/epoch - 120ms/step
# Epoch 8/50
# 28/28 - 5s - loss: 0.3885 - accuracy: 0.8664 - val_loss: 0.4385 - val_accuracy: 0.8414 - lr: 0.0010 - 5s/epoch - 170ms/step
# Epoch 9/50
# 28/28 - 4s - loss: 0.3867 - accuracy: 0.8681 - val_loss: 0.4320 - val_accuracy: 0.8481 - lr: 0.0010 - 4s/epoch - 135ms/step
# Epoch 10/50
# 28/28 - 4s - loss: 0.3812 - accuracy: 0.8720 - val_loss: 0.4390 - val_accuracy: 0.8431 - lr: 0.0010 - 4s/epoch - 138ms/step
# Epoch 11/50
# 28/28 - 2s - loss: 0.3744 - accuracy: 0.8740 - val_loss: 0.4298 - val_accuracy: 0.8467 - lr: 0.0010 - 2s/epoch - 65ms/step
# Epoch 12/50
# 28/28 - 3s - loss: 0.3687 - accuracy: 0.8757 - val_loss: 0.4301 - val_accuracy: 0.8543 - lr: 0.0010 - 3s/epoch - 116ms/step
# Epoch 13/50
# 28/28 - 3s - loss: 0.3696 - accuracy: 0.8785 - val_loss: 0.4259 - val_accuracy: 0.8549 - lr: 0.0010 - 3s/epoch - 98ms/step
# Epoch 14/50
# 28/28 - 2s - loss: 0.3703 - accuracy: 0.8743 - val_loss: 0.4249 - val_accuracy: 0.8484 - lr: 0.0010 - 2s/epoch - 68ms/step
# Epoch 15/50
# 28/28 - 2s - loss: 0.3649 - accuracy: 0.8794 - val_loss: 0.4220 - val_accuracy: 0.8512 - lr: 0.0010 - 2s/epoch - 64ms/step
# Epoch 16/50
# 28/28 - 2s - loss: 0.3683 - accuracy: 0.8797 - val_loss: 0.4216 - val_accuracy: 0.8507 - lr: 0.0010 - 2s/epoch - 63ms/step
# Epoch 17/50
# 28/28 - 2s - loss: 0.3687 - accuracy: 0.8723 - val_loss: 0.4451 - val_accuracy: 0.8375 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 18/50
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 2s - loss: 0.3746 - accuracy: 0.8729 - val_loss: 0.4244 - val_accuracy: 0.8459 - lr: 0.0010 - 2s/epoch - 68ms/step
# Epoch 19/50
# 28/28 - 4s - loss: 0.3615 - accuracy: 0.8777 - val_loss: 0.4218 - val_accuracy: 0.8529 - lr: 1.0000e-04 - 4s/epoch - 132ms/step
# Epoch 20/50
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 2s - loss: 0.3567 - accuracy: 0.8802 - val_loss: 0.4222 - val_accuracy: 0.8543 - lr: 1.0000e-04 - 2s/epoch - 84ms/step
# Epoch 21/50
# 28/28 - 2s - loss: 0.3561 - accuracy: 0.8831 - val_loss: 0.4216 - val_accuracy: 0.8546 - lr: 1.0000e-05 - 2s/epoch - 71ms/step
# Epoch 22/50
# 28/28 - 2s - loss: 0.3571 - accuracy: 0.8817 - val_loss: 0.4214 - val_accuracy: 0.8543 - lr: 1.0000e-05 - 2s/epoch - 70ms/step
# Epoch 23/50
# 28/28 - 2s - loss: 0.3565 - accuracy: 0.8825 - val_loss: 0.4211 - val_accuracy: 0.8537 - lr: 1.0000e-05 - 2s/epoch - 69ms/step
# Epoch 24/50
# 28/28 - 2s - loss: 0.3565 - accuracy: 0.8831 - val_loss: 0.4211 - val_accuracy: 0.8537 - lr: 1.0000e-05 - 2s/epoch - 69ms/step
# Epoch 25/50
# 28/28 - 3s - loss: 0.3563 - accuracy: 0.8814 - val_loss: 0.4208 - val_accuracy: 0.8535 - lr: 1.0000e-05 - 3s/epoch - 90ms/step
# Epoch 26/50
# 28/28 - 4s - loss: 0.3568 - accuracy: 0.8828 - val_loss: 0.4212 - val_accuracy: 0.8543 - lr: 1.0000e-05 - 4s/epoch - 127ms/step
# Epoch 27/50
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 2s - loss: 0.3563 - accuracy: 0.8828 - val_loss: 0.4214 - val_accuracy: 0.8543 - lr: 1.0000e-05 - 2s/epoch - 66ms/step
# Epoch 28/50
# 28/28 - 2s - loss: 0.3561 - accuracy: 0.8814 - val_loss: 0.4214 - val_accuracy: 0.8543 - lr: 1.0000e-06 - 2s/epoch - 60ms/step
# Epoch 29/50
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 2s - loss: 0.3572 - accuracy: 0.8828 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-06 - 2s/epoch - 67ms/step
# Epoch 30/50
# 28/28 - 2s - loss: 0.3556 - accuracy: 0.8822 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-07 - 2s/epoch - 68ms/step
# Epoch 31/50
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 2s - loss: 0.3565 - accuracy: 0.8822 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-07 - 2s/epoch - 68ms/step
# Epoch 32/50
# 28/28 - 3s - loss: 0.3568 - accuracy: 0.8819 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-08 - 3s/epoch - 123ms/step
# Epoch 33/50
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 28/28 - 2s - loss: 0.3562 - accuracy: 0.8822 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-08 - 2s/epoch - 87ms/step
# Epoch 34/50
# 28/28 - 3s - loss: 0.3567 - accuracy: 0.8808 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-09 - 3s/epoch - 95ms/step
# Epoch 35/50
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 28/28 - 2s - loss: 0.3570 - accuracy: 0.8822 - val_loss: 0.4213 - val_accuracy: 0.8543 - lr: 1.0000e-09 - 2s/epoch - 77ms/step
# Epoch 35: early stopping

# %%
# plot training history
Tloss_CNN=history.history['loss']
Vloss_CNN=history.history['val_loss']
plt.plot(Tloss_CNN,color='red')
plt.plot(Vloss_CNN,color='orange')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = model.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='red', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 1s 10ms/step
# Predict shape:
# (3569, 1)

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc

df = pd.DataFrame()
fpr = {}
tpr = {}
auc1 = {}

fpr, tpr, threshold = roc_curve(ztest,predict)

auc1 = auc(fpr, tpr)
print(type(auc1))
plt.plot(fpr,tpr, label='auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("CNN model")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')
# Out:
# <class 'numpy.float64'>

# %% [markdown]
# # **MLP Model**

# %%
#MLP
dropoutRateMLP = dropoutRate

batch_sizeMLP = batch_size
n_epochsMLP = n_epochs
n_neuronsMLP = n_neurons

####
inputList = Input(shape=(featureArrayLength))

x = Dense(n_neuronsMLP, activation='relu')(inputList[:,:,0])
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)

####
modelMLP = Model(inputs=inputList, outputs=output)

# %%
modelMLP.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
modelMLP.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 1)]          0
#
#  tf.__operators__.getitem (S  (None, 300)              0
#  licingOpLambda)
#
#  dense_2 (Dense)             (None, 1024)              308224
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 309,249
# Trainable params: 309,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train
history = modelMLP.fit( ytrain, ztrain, epochs=n_epochsMLP, batch_size=batch_sizeMLP, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/50
# 28/28 - 2s - loss: 0.7462 - accuracy: 0.6036 - val_loss: 0.6236 - val_accuracy: 0.5996 - lr: 0.0010 - 2s/epoch - 87ms/step
# Epoch 2/50
# 28/28 - 1s - loss: 0.5663 - accuracy: 0.7166 - val_loss: 0.5660 - val_accuracy: 0.7380 - lr: 0.0010 - 614ms/epoch - 22ms/step
# Epoch 3/50
# 28/28 - 1s - loss: 0.5308 - accuracy: 0.7537 - val_loss: 0.5580 - val_accuracy: 0.7302 - lr: 0.0010 - 686ms/epoch - 25ms/step
# Epoch 4/50
# 28/28 - 1s - loss: 0.5100 - accuracy: 0.7684 - val_loss: 0.5426 - val_accuracy: 0.7391 - lr: 0.0010 - 589ms/epoch - 21ms/step
# Epoch 5/50
# 28/28 - 0s - loss: 0.5095 - accuracy: 0.7667 - val_loss: 0.5353 - val_accuracy: 0.7377 - lr: 0.0010 - 429ms/epoch - 15ms/step
# Epoch 6/50
# 28/28 - 0s - loss: 0.5160 - accuracy: 0.7605 - val_loss: 0.5721 - val_accuracy: 0.7153 - lr: 0.0010 - 456ms/epoch - 16ms/step
# Epoch 7/50
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 0s - loss: 0.4987 - accuracy: 0.7701 - val_loss: 0.5403 - val_accuracy: 0.7383 - lr: 0.0010 - 423ms/epoch - 15ms/step
# Epoch 8/50
# 28/28 - 0s - loss: 0.4938 - accuracy: 0.7763 - val_loss: 0.5286 - val_accuracy: 0.7459 - lr: 1.0000e-04 - 473ms/epoch - 17ms/step
# Epoch 9/50
# 28/28 - 0s - loss: 0.4882 - accuracy: 0.7766 - val_loss: 0.5279 - val_accuracy: 0.7417 - lr: 1.0000e-04 - 464ms/epoch - 17ms/step
# Epoch 10/50
# 28/28 - 1s - loss: 0.4901 - accuracy: 0.7763 - val_loss: 0.5367 - val_accuracy: 0.7335 - lr: 1.0000e-04 - 518ms/epoch - 19ms/step
# Epoch 11/50
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 0s - loss: 0.4908 - accuracy: 0.7783 - val_loss: 0.5286 - val_accuracy: 0.7400 - lr: 1.0000e-04 - 452ms/epoch - 16ms/step
# Epoch 12/50
# 28/28 - 1s - loss: 0.4896 - accuracy: 0.7766 - val_loss: 0.5264 - val_accuracy: 0.7433 - lr: 1.0000e-05 - 722ms/epoch - 26ms/step
# Epoch 13/50
# 28/28 - 1s - loss: 0.4878 - accuracy: 0.7758 - val_loss: 0.5266 - val_accuracy: 0.7428 - lr: 1.0000e-05 - 862ms/epoch - 31ms/step
# Epoch 14/50
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 1s - loss: 0.4874 - accuracy: 0.7800 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-05 - 739ms/epoch - 26ms/step
# Epoch 15/50
# 28/28 - 1s - loss: 0.4881 - accuracy: 0.7780 - val_loss: 0.5264 - val_accuracy: 0.7428 - lr: 1.0000e-06 - 649ms/epoch - 23ms/step
# Epoch 16/50
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 1s - loss: 0.4855 - accuracy: 0.7724 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-06 - 624ms/epoch - 22ms/step
# Epoch 17/50
# 28/28 - 1s - loss: 0.4840 - accuracy: 0.7800 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-07 - 735ms/epoch - 26ms/step
# Epoch 18/50
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 1s - loss: 0.4917 - accuracy: 0.7780 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-07 - 686ms/epoch - 24ms/step
# Epoch 19/50
# 28/28 - 0s - loss: 0.4896 - accuracy: 0.7775 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-08 - 471ms/epoch - 17ms/step
# Epoch 20/50
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 28/28 - 0s - loss: 0.4863 - accuracy: 0.7789 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-08 - 463ms/epoch - 17ms/step
# Epoch 21/50
# 28/28 - 0s - loss: 0.4887 - accuracy: 0.7749 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-09 - 468ms/epoch - 17ms/step
# Epoch 22/50
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 28/28 - 0s - loss: 0.4890 - accuracy: 0.7769 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-09 - 467ms/epoch - 17ms/step
# Epoch 23/50
# 28/28 - 0s - loss: 0.4883 - accuracy: 0.7789 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-10 - 431ms/epoch - 15ms/step
# Epoch 24/50
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 28/28 - 0s - loss: 0.4865 - accuracy: 0.7814 - val_loss: 0.5263 - val_accuracy: 0.7428 - lr: 1.0000e-10 - 482ms/epoch - 17ms/step
# Epoch 24: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], color='blue', label='training MLP')
plt.plot(history.history['val_loss'], color='cyan', label='validation MLP')
plt.plot(Tloss_CNN,color='red',alpha=0.35, label='training CNN')
plt.plot(Vloss_CNN,color='orange',alpha=0.35, label='validation CNN')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = modelMLP.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='blue', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 0s 2ms/step
# Predict shape:
# (3569, 1)

# %%
plt.plot(fpr,tpr, label='CNN: auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red',alpha=0.35)

df = pd.DataFrame()
fprMLP = {}
tprMLP = {}
auc1MLP = {}

fprMLP, tprMLP, thresholdMLP = roc_curve(ztest,predict)

auc1MLP = auc(fprMLP, tprMLP)

plt.plot(fprMLP,tprMLP, label='MLP: auc='+str(np.round(auc1MLP*100,2))+'% , # neurons='+str(n_neuronsMLP), color='blue')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("ROC curve")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')

print('*****Summary of Hyperparameters**')
print('Drop Out CNN:', dropoutRate)
print('# neurons CNN:', n_neurons)
print('batch size CNN:', batch_size)
print('*****')
print('Drop Out MLP:', dropoutRateMLP)
print('# neurons MLP:', n_neuronsMLP)
print('batch size MLP:', batch_sizeMLP)
# Out:
# *****Summary of Hyperparameters**
# Drop Out CNN: 0.25
# # neurons CNN: 1024
# batch size CNN: 128
# *****
# Drop Out MLP: 0.25
# # neurons MLP: 1024
# batch size MLP: 128

# %% [markdown]
# # **DISCUSSION OF RESULTS**
#
# 1.   **Dataset choise**
#
# To reach our binary classification task, 2 different pairs of dataset (2 for the *train* task and 2 for the *test* task) have been produced. The first train dataset is more unbalanced in the 2 class,
#
# 2.   ****
