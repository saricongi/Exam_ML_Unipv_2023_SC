# %% [markdown]
# <a href="https://colab.research.google.com/github/saricongi/Exam_ML_Unipv_2023_SC/blob/master/1D_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
# directory = 'https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git'
# !git clone https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git
# !curl https://github.com/saricongiExam_ML_Unipv_2023_SC.git
# Out:
# Cloning into 'Exam_ML_Unipv_2023_SC'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 42 (delta 5), reused 0 (delta 0), pack-reused 27
# Receiving objects: 100% (42/42), 50.16 MiB | 12.51 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# Updating files: 100% (10/10), done.
# Not Found

# %% [markdown]
# The dataset is made by transmission optical spectra of optical resonators integrated on a silicon chip as the one shown here:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/device.png?raw=1" width="800"/>
# </div>
#
# A typical mesured spectrum can have a shape as the following:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/Example.png?raw=1" width="600"/>
# </div>
#
# The analysis of this type of spectra with theoretical models is not straightforward, because one single resonance is given by the contribution of both ring resonators, with interference occurring between the two. For application in light storing and optical switches, we are interested on the devices and wavelength ranges where double peaks occur.
#
# The goal of this ML project is to correctly recognize if a resonance is showing the  single-peak or the double-peak behaviour. Therefore, each spectrum has a label *z* to classify it into the two possible groups (*binary classification problem*).
#
# Since it is a periodic pattern, the full wavelength (*wl*) scan has been split in different arrays of equal length (*300*), each of them contains a single resonance. In this way, more than 6000 resonance spectra have been recorded, divided in *train* and *test* datasets.
#
# Moreover, the information on the absolute wl is not important for the task, thus we are going to normalize it (*x* between 0 and 1). Since independetly of the resonance position we want to be able to classify the peaks, our problem exhibits *translational symmetry*. For this reason, the model implemented is a **1D CNN**. For comparison, also a more simple **MLP** model has been implemented.
#
#
# **DATASETs STRUCTURE:**
#
# * **Train dataset = 3532 spectra**
# * **Test (or evaluation) dataset = 3569 spectra**
# * **1 spectrum = 300 wavelength points -> y**.
# * **Nb labels = 2 -> z**, *z=0* if there is only one visible peak, *z=1* if the resonance is splittend into 2 peaks.
#
# **ON THE FOLLOWING NOTEBOOK:**
#
# The notebook is already runned on the optimized conditions. The hyper-parameters used for the optimization are:
# * the number of neurons;
# * the number of convolution layer (*conv1D*): 0 (*MLP* case), 1, 2 and 3.
#
# The results are discussed in the last paragraph.

# %% [markdown]
# ## **Train Dataset:**

# %%
## Train DataSet
url = '/content/Exam_ML_Unipv_2023_SC/DataSet_train.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=0
j=24
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=2
j=30
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=3
j=35
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">

# %% [markdown]
# ### **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(0,NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytrain = []
xtrain = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytrain = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytrain.append(my_ytrain)
      target.append(my_target)
      xtrain.append(x)

ytrain=np.array(ytrain).reshape(-1,300,1)
ztrain=np.array(target).reshape(-1,1)
xtrain=np.array(xtrain).reshape(-1,300,1)

print("xtrain shape: ", xtrain.shape)
print("ytrain shape: ", ytrain.shape)
print("ztrain shape: ", ztrain.shape)

hf.close()
# Out:
# xtrain shape:  (3532, 300, 1)
# ytrain shape:  (3532, 300, 1)
# ztrain shape:  (3532, 1)

# %% [markdown]
# ### Let's check that in the train dataset the two labels are well distributed:

# %%
plt.hist(ztrain, len(ztrain[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Train Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztrain[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **1D CNN MODEL**

# %%
# keras imports
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Conv1D, AveragePooling1D, Dropout, Flatten
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN

# %%
featureArrayLength = (ytrain.shape[1],ytrain.shape[2])
dropoutRate = 0.25

batch_size = 128
n_epochs = 80
n_neurons = 16

# CNN 1D
####
inputList = Input(shape=(featureArrayLength))
x = Conv1D(20, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(inputList)
x = AveragePooling1D(pool_size=2)(x)
# #
x = Conv1D(40, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=4)(x)
# #
x = Conv1D(60, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=8)(x)

# (inputList)
x = Flatten()(x)
x = Dense(n_neurons, activation='relu')(x)
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)
####
model = Model(inputs=inputList, outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 1)]          0
#
#  conv1d (Conv1D)             (None, 298, 20)           80
#
#  average_pooling1d (AverageP  (None, 149, 20)          0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 147, 40)           2440
#
#  average_pooling1d_1 (Averag  (None, 36, 40)           0
#  ePooling1D)
#
#  conv1d_2 (Conv1D)           (None, 34, 60)            7260
#
#  average_pooling1d_2 (Averag  (None, 4, 60)            0
#  ePooling1D)
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 16)                3856
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13,653
# Trainable params: 13,653
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Test Dataset**

# %%
## Test DataSet

url = '/content/Exam_ML_Unipv_2023_SC/DataSet_test.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=4
j=26
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=2
ResNb2=21

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=6
j=32
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=7
j=40
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x2": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x43', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y43', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z43', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">

# %% [markdown]
# ## **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(4,4+NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytest = []
xtest = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytest = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytest.append(my_ytest)
      target.append(my_target)
      xtest.append(x)

ytest=np.array(ytest).reshape(-1,300,1)
ztest=np.array(target).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,300,1)
print(ztest.shape, ytest.shape, xtest.shape)

# ztest = to_categorical(target, num_classes = 2)
# print("New dimension of test target:")
# print(ztest.shape)

# hf.close()

plt.hist(ztest, len(ztest[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Test Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztest[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# (3569, 1) (3569, 300, 1) (3569, 300, 1)
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **TRAIN**

# %%
# train
history = model.fit( ytrain, ztrain, epochs=n_epochs, batch_size=batch_size, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/80
# 28/28 - 7s - loss: 0.6903 - accuracy: 0.5362 - val_loss: 0.6919 - val_accuracy: 0.4937 - lr: 0.0010 - 7s/epoch - 266ms/step
# Epoch 2/80
# 28/28 - 2s - loss: 0.6892 - accuracy: 0.5436 - val_loss: 0.6945 - val_accuracy: 0.4937 - lr: 0.0010 - 2s/epoch - 65ms/step
# Epoch 3/80
# 28/28 - 3s - loss: 0.6847 - accuracy: 0.5447 - val_loss: 0.6856 - val_accuracy: 0.4982 - lr: 0.0010 - 3s/epoch - 117ms/step
# Epoch 4/80
# 28/28 - 2s - loss: 0.6705 - accuracy: 0.5912 - val_loss: 0.6567 - val_accuracy: 0.6996 - lr: 0.0010 - 2s/epoch - 66ms/step
# Epoch 5/80
# 28/28 - 2s - loss: 0.6212 - accuracy: 0.6920 - val_loss: 0.5839 - val_accuracy: 0.7767 - lr: 0.0010 - 2s/epoch - 54ms/step
# Epoch 6/80
# 28/28 - 2s - loss: 0.5303 - accuracy: 0.7642 - val_loss: 0.4824 - val_accuracy: 0.8232 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 7/80
# 28/28 - 2s - loss: 0.4317 - accuracy: 0.8148 - val_loss: 0.4242 - val_accuracy: 0.8190 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 8/80
# 28/28 - 2s - loss: 0.3576 - accuracy: 0.8550 - val_loss: 0.3430 - val_accuracy: 0.8739 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 9/80
# 28/28 - 2s - loss: 0.2822 - accuracy: 0.8927 - val_loss: 0.3058 - val_accuracy: 0.8890 - lr: 0.0010 - 2s/epoch - 87ms/step
# Epoch 10/80
# 28/28 - 2s - loss: 0.2375 - accuracy: 0.9094 - val_loss: 0.2785 - val_accuracy: 0.9011 - lr: 0.0010 - 2s/epoch - 76ms/step
# Epoch 11/80
# 28/28 - 2s - loss: 0.2142 - accuracy: 0.9224 - val_loss: 0.2674 - val_accuracy: 0.9075 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 12/80
# 28/28 - 2s - loss: 0.1987 - accuracy: 0.9255 - val_loss: 0.2573 - val_accuracy: 0.9148 - lr: 0.0010 - 2s/epoch - 58ms/step
# Epoch 13/80
# 28/28 - 2s - loss: 0.1872 - accuracy: 0.9315 - val_loss: 0.2531 - val_accuracy: 0.9171 - lr: 0.0010 - 2s/epoch - 63ms/step
# Epoch 14/80
# 28/28 - 2s - loss: 0.1812 - accuracy: 0.9403 - val_loss: 0.2548 - val_accuracy: 0.9123 - lr: 0.0010 - 2s/epoch - 66ms/step
# Epoch 15/80
# 28/28 - 2s - loss: 0.1695 - accuracy: 0.9391 - val_loss: 0.2360 - val_accuracy: 0.9252 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 16/80
# 28/28 - 2s - loss: 0.1531 - accuracy: 0.9485 - val_loss: 0.2410 - val_accuracy: 0.9314 - lr: 0.0010 - 2s/epoch - 83ms/step
# Epoch 17/80
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 2s - loss: 0.1540 - accuracy: 0.9465 - val_loss: 0.2400 - val_accuracy: 0.9308 - lr: 0.0010 - 2s/epoch - 88ms/step
# Epoch 18/80
# 28/28 - 2s - loss: 0.1470 - accuracy: 0.9510 - val_loss: 0.2417 - val_accuracy: 0.9339 - lr: 1.0000e-04 - 2s/epoch - 57ms/step
# Epoch 19/80
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 2s - loss: 0.1450 - accuracy: 0.9522 - val_loss: 0.2433 - val_accuracy: 0.9325 - lr: 1.0000e-04 - 2s/epoch - 77ms/step
# Epoch 20/80
# 28/28 - 3s - loss: 0.1407 - accuracy: 0.9539 - val_loss: 0.2399 - val_accuracy: 0.9350 - lr: 1.0000e-05 - 3s/epoch - 110ms/step
# Epoch 21/80
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 2s - loss: 0.1423 - accuracy: 0.9524 - val_loss: 0.2378 - val_accuracy: 0.9356 - lr: 1.0000e-05 - 2s/epoch - 68ms/step
# Epoch 22/80
# 28/28 - 3s - loss: 0.1412 - accuracy: 0.9536 - val_loss: 0.2377 - val_accuracy: 0.9356 - lr: 1.0000e-06 - 3s/epoch - 118ms/step
# Epoch 23/80
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 2s - loss: 0.1433 - accuracy: 0.9558 - val_loss: 0.2376 - val_accuracy: 0.9356 - lr: 1.0000e-06 - 2s/epoch - 87ms/step
# Epoch 24/80
# 28/28 - 3s - loss: 0.1444 - accuracy: 0.9502 - val_loss: 0.2375 - val_accuracy: 0.9356 - lr: 1.0000e-07 - 3s/epoch - 102ms/step
# Epoch 25/80
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 2s - loss: 0.1422 - accuracy: 0.9527 - val_loss: 0.2375 - val_accuracy: 0.9356 - lr: 1.0000e-07 - 2s/epoch - 74ms/step
# Epoch 25: early stopping

# %%
# plot training history
Tloss_CNN=history.history['loss']
Vloss_CNN=history.history['val_loss']
plt.plot(Tloss_CNN,color='red')
plt.plot(Vloss_CNN,color='orange')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = model.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='red', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 1s 9ms/step
# Predict shape:
# (3569, 1)

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc

df = pd.DataFrame()
fpr = {}
tpr = {}
auc1 = {}

fpr, tpr, threshold = roc_curve(ztest,predict)

auc1 = auc(fpr, tpr)
print(type(auc1))
plt.plot(fpr,tpr, label='auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("CNN model")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')
# Out:
# <class 'numpy.float64'>

# %% [markdown]
# # **MLP Model**

# %%
#MLP
dropoutRateMLP = dropoutRate

batch_sizeMLP = batch_size
n_epochsMLP = n_epochs
n_neuronsMLP = n_neurons

####
inputList = Input(shape=(featureArrayLength))

x = Dense(n_neuronsMLP, activation='relu')(inputList[:,:,0])
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)

####
modelMLP = Model(inputs=inputList, outputs=output)

# %%
modelMLP.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
modelMLP.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 1)]          0
#
#  tf.__operators__.getitem (S  (None, 300)              0
#  licingOpLambda)
#
#  dense_2 (Dense)             (None, 16)                4816
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 4,833
# Trainable params: 4,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train
history = modelMLP.fit( ytrain, ztrain, epochs=n_epochsMLP, batch_size=batch_sizeMLP, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/80
# 28/28 - 1s - loss: 0.6899 - accuracy: 0.5886 - val_loss: 0.6214 - val_accuracy: 0.7456 - lr: 0.0010 - 989ms/epoch - 35ms/step
# Epoch 2/80
# 28/28 - 0s - loss: 0.6003 - accuracy: 0.7225 - val_loss: 0.5764 - val_accuracy: 0.7638 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 3/80
# 28/28 - 0s - loss: 0.5590 - accuracy: 0.7463 - val_loss: 0.5309 - val_accuracy: 0.8008 - lr: 0.0010 - 122ms/epoch - 4ms/step
# Epoch 4/80
# 28/28 - 0s - loss: 0.5309 - accuracy: 0.7525 - val_loss: 0.5071 - val_accuracy: 0.7887 - lr: 0.0010 - 159ms/epoch - 6ms/step
# Epoch 5/80
# 28/28 - 0s - loss: 0.4882 - accuracy: 0.7998 - val_loss: 0.4740 - val_accuracy: 0.8210 - lr: 0.0010 - 198ms/epoch - 7ms/step
# Epoch 6/80
# 28/28 - 0s - loss: 0.4637 - accuracy: 0.8038 - val_loss: 0.4559 - val_accuracy: 0.8299 - lr: 0.0010 - 171ms/epoch - 6ms/step
# Epoch 7/80
# 28/28 - 0s - loss: 0.4522 - accuracy: 0.8038 - val_loss: 0.4440 - val_accuracy: 0.8296 - lr: 0.0010 - 207ms/epoch - 7ms/step
# Epoch 8/80
# 28/28 - 0s - loss: 0.4400 - accuracy: 0.8044 - val_loss: 0.4385 - val_accuracy: 0.8055 - lr: 0.0010 - 264ms/epoch - 9ms/step
# Epoch 9/80
# 28/28 - 0s - loss: 0.4286 - accuracy: 0.8140 - val_loss: 0.4179 - val_accuracy: 0.8282 - lr: 0.0010 - 184ms/epoch - 7ms/step
# Epoch 10/80
# 28/28 - 0s - loss: 0.4240 - accuracy: 0.8137 - val_loss: 0.4232 - val_accuracy: 0.8033 - lr: 0.0010 - 129ms/epoch - 5ms/step
# Epoch 11/80
# 28/28 - 0s - loss: 0.4192 - accuracy: 0.8163 - val_loss: 0.4041 - val_accuracy: 0.8282 - lr: 0.0010 - 133ms/epoch - 5ms/step
# Epoch 12/80
# 28/28 - 0s - loss: 0.4088 - accuracy: 0.8160 - val_loss: 0.4048 - val_accuracy: 0.8316 - lr: 0.0010 - 123ms/epoch - 4ms/step
# Epoch 13/80
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 0s - loss: 0.3994 - accuracy: 0.8191 - val_loss: 0.4060 - val_accuracy: 0.8100 - lr: 0.0010 - 177ms/epoch - 6ms/step
# Epoch 14/80
# 28/28 - 0s - loss: 0.3932 - accuracy: 0.8216 - val_loss: 0.3947 - val_accuracy: 0.8308 - lr: 1.0000e-04 - 159ms/epoch - 6ms/step
# Epoch 15/80
# 28/28 - 0s - loss: 0.3951 - accuracy: 0.8194 - val_loss: 0.3955 - val_accuracy: 0.8282 - lr: 1.0000e-04 - 150ms/epoch - 5ms/step
# Epoch 16/80
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 0s - loss: 0.3940 - accuracy: 0.8253 - val_loss: 0.3951 - val_accuracy: 0.8280 - lr: 1.0000e-04 - 155ms/epoch - 6ms/step
# Epoch 17/80
# 28/28 - 0s - loss: 0.3948 - accuracy: 0.8205 - val_loss: 0.3952 - val_accuracy: 0.8274 - lr: 1.0000e-05 - 168ms/epoch - 6ms/step
# Epoch 18/80
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 0s - loss: 0.3930 - accuracy: 0.8264 - val_loss: 0.3949 - val_accuracy: 0.8271 - lr: 1.0000e-05 - 128ms/epoch - 5ms/step
# Epoch 19/80
# 28/28 - 0s - loss: 0.3929 - accuracy: 0.8256 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-06 - 148ms/epoch - 5ms/step
# Epoch 20/80
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 0s - loss: 0.3881 - accuracy: 0.8293 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-06 - 169ms/epoch - 6ms/step
# Epoch 21/80
# 28/28 - 0s - loss: 0.3908 - accuracy: 0.8361 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-07 - 163ms/epoch - 6ms/step
# Epoch 22/80
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 0s - loss: 0.3994 - accuracy: 0.8205 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-07 - 142ms/epoch - 5ms/step
# Epoch 23/80
# 28/28 - 0s - loss: 0.3949 - accuracy: 0.8267 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-08 - 182ms/epoch - 6ms/step
# Epoch 24/80
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 28/28 - 0s - loss: 0.3979 - accuracy: 0.8222 - val_loss: 0.3949 - val_accuracy: 0.8280 - lr: 1.0000e-08 - 172ms/epoch - 6ms/step
# Epoch 24: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], color='blue', label='training MLP')
plt.plot(history.history['val_loss'], color='cyan', label='validation MLP')
plt.plot(Tloss_CNN,color='red',alpha=0.35, label='training CNN')
plt.plot(Vloss_CNN,color='orange',alpha=0.35, label='validation CNN')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = modelMLP.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='blue', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 0s 2ms/step
# Predict shape:
# (3569, 1)

# %%
plt.plot(fpr,tpr, label='CNN: auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red',alpha=0.35)

df = pd.DataFrame()
fprMLP = {}
tprMLP = {}
auc1MLP = {}

fprMLP, tprMLP, thresholdMLP = roc_curve(ztest,predict)

auc1MLP = auc(fprMLP, tprMLP)

plt.plot(fprMLP,tprMLP, label='MLP: auc='+str(np.round(auc1MLP*100,2))+'% , # neurons='+str(n_neuronsMLP), color='blue')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("ROC curve")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')

print('*****Summary of Hyperparameters**')
print('Drop Out CNN:', dropoutRate)
print('# neurons CNN:', n_neurons)
print('batch size CNN:', batch_size)
print('*****')
print('Drop Out MLP:', dropoutRateMLP)
print('# neurons MLP:', n_neuronsMLP)
print('batch size MLP:', batch_sizeMLP)
# Out:
# *****Summary of Hyperparameters**
# Drop Out CNN: 0.25
# # neurons CNN: 16
# batch size CNN: 128
# *****
# Drop Out MLP: 0.25
# # neurons MLP: 16
# batch size MLP: 128

# %% [markdown]
# # **RESULTS**

# %%
import numpy as np
import matplotlib.pyplot as plt

N_neurons=[4,8,32,128,258]
Nb_parCNN=[12009,23937,95505,381777,769437]
Nb_parMLP=[1209,2417,9665,38657,77917]
Auc_CNN=[93.15,93.18,92.08,96.65,96.93]
Auc_MLP=[50.76,90.06,91.09,91.41,95.79]
Lt_CNN=[0.4,0.4,0.39,0.14,0.15]
Lt_MLP=[0.69,0.42,0.37,0.36,0.23]
Lv_CNN=[0.36,0.36,0.36,0.24,0.23]
Lv_MLP=[0.69,0.41,0.38,0.37,0.27]
Nb_parCNN=np.array(Nb_parCNN)
Nb_parMLP=np.array(Nb_parMLP)

CNN2=[32,48665,0.18,0.23,93.72]
CNN3=[16,13653,0.13,0.23,97.32]

fig, (ax1,ax2) = plt.subplots(figsize=(10,4), nrows=1, ncols=2, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(50,100)
  # ax.set_xlim(0,1)
  ax.set_ylabel('Accuracy (%)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

plt.suptitle('CNN vs MLP')

ax1.plot(N_neurons,Auc_CNN,color='red',marker='o')
ax1.plot(N_neurons,Auc_MLP,color='blue',marker='o')
ax1.scatter(32,93.72,color='crimson',marker='x')
ax1.scatter(16,97.32,color='crimson',marker='*')
ax1.set_xlabel('# neurons')
ax2.plot(Nb_parCNN,Auc_CNN,color='red',marker='o', label='CNN 1')
ax2.plot(Nb_parMLP,Auc_MLP,color='blue',marker='o', label='MLP')
ax2.scatter(48665,93.72,color='crimson',marker='x', label='CNN 2')
ax2.scatter(13653,97.32,color='crimson',marker='*',label='CNN 3')
ax2.semilogx()
ax2.set_xlabel('# parameters')


ax2.legend()
plt.show()

fig, (ax1,ax2) = plt.subplots(figsize=(10,4), nrows=1, ncols=2, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(0,1)
  # ax.set_xlim(0,1)
  ax.set_ylabel('Loss')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

plt.suptitle('CNN vs MLP')

ax1.plot(N_neurons,Lt_CNN,color='red',marker='o')
ax1.plot(N_neurons,Lv_CNN,color='orange',marker='s')
ax1.plot(N_neurons,Lt_MLP,color='blue',marker='o')
ax1.plot(N_neurons,Lv_MLP,color='cyan',marker='s')
ax1.set_xlabel('# neurons')
ax2.plot(Nb_parCNN,Lt_CNN,color='red',marker='o', label='CNN 1 - test')
ax2.plot(Nb_parCNN,Lv_CNN,color='orange',marker='s', label='CNN 1 - validation')
ax2.plot(Nb_parMLP,Lt_MLP,color='blue',marker='o', label='MLP - test')
ax2.plot(Nb_parMLP,Lv_MLP,color='cyan',marker='s', label='MLP - validation')
ax2.semilogx()
ax2.set_xlabel('# parameters')

ax2.legend()
plt.show()

# %% [markdown]
# ## **DISCUSSION OF THE RESULTS**
#
# The binary classification task here proposed has been addressed by the use of 1DCNNs. The hyper-parameters used for the optimization of the neural network are shown in the above graphs: number of neurons (and, as a consequence, the number of network's parameters) and number of convolution layers (0, 1, 2 and finally 3).
#
# The classification of single or double-peak is a task simple enough to be faced efficiently by an MLP model, has shown by the blue (and cyan) points in the accuracy and loss graphs. However, one convolution layer (red and orange points, *CNN 1*) allows the NN to learn better and reach higher accuracy, although with a higher number of parameters.
#
# The best compromise can be found by adding a total of 3 convolution layers, reaching high accuracy (>95%) with a low number of neurons (16) and parameters (around 1400). The notebook is currently runned in this best configuration.
