# %% [markdown]
# <a href="https://colab.research.google.com/github/saricongi/Exam_ML_Unipv_2023_SC/blob/master/1D_CNN_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.sparse import load_npz
import h5py

# %%
# directory = 'https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git'
# !git clone https://github.com/saricongi/Exam_ML_Unipv_2023_SC.git
# !curl https://github.com/saricongiExam_ML_Unipv_2023_SC.git
# Out:
# Cloning into 'Exam_ML_Unipv_2023_SC'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 39 (delta 4), reused 0 (delta 0), pack-reused 27
# Receiving objects: 100% (39/39), 49.29 MiB | 11.01 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Updating files: 100% (9/9), done.
# Not Found

# %% [markdown]
# The dataset is made by transmission optical spectra of optical resonators integrated on a silicon chip as the one shown here:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/device.png?raw=1" width="800"/>
# </div>
#
# A typical mesured spectrum can have a shape as the following:
# <div>
# <img src="https://github.com/saricongi/Exam_ML_Unipv_2023_SC/blob/master/Example.png?raw=1" width="600"/>
# </div>
#
# The analysis of this type of spectra with theoretical models is not straightforward, because one single resonance is given by the contribution of both ring resonators, with interference occuring between the two. For application in light storing and optical switchers, we are interested on the devices and wavelength ranges where double peaks occurs.
#
# The goal of this ML project is to correctly recognize if a resonance is showing the  single-peak or the double-peak behaviour. Therefore, each spectrum has a label *z* to classify it into the two possible groups (*binary classification problem*).
#
# Since it is a periodic pattern, the full wavelength (*wl*) scan has been splitted in different arrays of equal length (*300*), each of them contains a single resonance. In this way, more than 6000 resonance spectra have been recorded, divided in *train* and *test* datasets.
#
# Moreover, the information on the absolute wl is not of our interest, thus we are going to normalize it (*x* between 0 and 1). Since independetly on the resonance position we want to be able to classify the peaks, our problem exibits *translational symmetry*. For this reason, the model implemented is a **1D CNN**.
#
#
# **DATASETs STRUCTURE:**
#
# * **Train dataset = 3532 spectra**
# * **Test (or evaluation) dataset = 3569 spectra**
# * **1 spectrum = 300 wavelength points -> y**.
# * **Nb labels = 2 -> z**, *z=0* if there is only one visible peak, *z=1* if the resonance is splittend into 2 peaks.

# %% [markdown]
# ## **Train Dataset:**

# %%
## Train DataSet
url = '/content/Exam_ML_Unipv_2023_SC/DataSet_train.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=0
j=24
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=2
j=30
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=3
j=35
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die0', 'Die1', 'Die2', 'Die3']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <ipython-input-3-db67ee1516f4>:35: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-db67ee1516f4>:36: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:45: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:46: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:47: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:69: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-db67ee1516f4>:70: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:71: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:76: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:77: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:78: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:100: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-3-db67ee1516f4>:101: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:102: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-3-db67ee1516f4>:107: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:108: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-3-db67ee1516f4>:109: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))

# %% [markdown]
# ### **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(0,NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytrain = []
xtrain = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytrain = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytrain.append(my_ytrain)
      target.append(my_target)
      xtrain.append(x)

ytrain=np.array(ytrain).reshape(-1,300,1)
ztrain=np.array(target).reshape(-1,1)
xtrain=np.array(xtrain).reshape(-1,300,1)

print("xtrain shape: ", xtrain.shape)
print("ytrain shape: ", ytrain.shape)
print("ztrain shape: ", ztrain.shape)

hf.close()
# Out:
# <ipython-input-4-5c7621e0802b>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytrain = np.array(sg.get('y'+str(k)))
# <ipython-input-4-5c7621e0802b>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# xtrain shape:  (3532, 300, 1)
# ytrain shape:  (3532, 300, 1)
# ztrain shape:  (3532, 1)

# %% [markdown]
# ### Let's check that in the train dataset there the two labels are well distributed:

# %%
plt.hist(ztrain, len(ztrain[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Train Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztrain[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **1D CNN MODEL**

# %%
# keras imports
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Conv1D, AveragePooling1D, Dropout, Flatten
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN

# %%
featureArrayLength = (ytrain.shape[1],ytrain.shape[2])
dropoutRate = 0.25

batch_size = 128
n_epochs = 80
n_neurons = 258

# CNN 1D
####
inputList = Input(shape=(featureArrayLength))
x = Conv1D(20, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(inputList)
x = AveragePooling1D(pool_size=2)(x)
# # #
# x = Conv1D(40, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
# x = AveragePooling1D(pool_size=4)(x)
# # #
# x = Conv1D(60, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
# x = AveragePooling1D(pool_size=8)(x)

# (inputList)
x = Flatten()(x)
x = Dense(n_neurons, activation='relu')(x)
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)
####
model = Model(inputs=inputList, outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 1)]          0
#
#  conv1d (Conv1D)             (None, 298, 20)           80
#
#  average_pooling1d (AverageP  (None, 149, 20)          0
#  ooling1D)
#
#  flatten (Flatten)           (None, 2980)              0
#
#  dense (Dense)               (None, 258)               769098
#
#  dropout (Dropout)           (None, 258)               0
#
#  dense_1 (Dense)             (None, 1)                 259
#
# =================================================================
# Total params: 769,437
# Trainable params: 769,437
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Test Dataset**

# %%
## Test DataSet

url = '/content/Exam_ML_Unipv_2023_SC/DataSet_test.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=4
j=26
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=2
ResNb2=21

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=6
j=32
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=7
j=40
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x2": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x43', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y43', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z43', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <ipython-input-9-cda9d4aa2d48>:36: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-cda9d4aa2d48>:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:38: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:46: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:47: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:48: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:70: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-cda9d4aa2d48>:71: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:72: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:77: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:78: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:79: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:101: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-9-cda9d4aa2d48>:102: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:103: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-9-cda9d4aa2d48>:108: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:109: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-9-cda9d4aa2d48>:110: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))

# %% [markdown]
# ## **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(4,4+NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytest = []
xtest = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytest = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytest.append(my_ytest)
      target.append(my_target)
      xtest.append(x)

ytest=np.array(ytest).reshape(-1,300,1)
ztest=np.array(target).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,300,1)
print(ztest.shape, ytest.shape, xtest.shape)

# ztest = to_categorical(target, num_classes = 2)
# print("New dimension of test target:")
# print(ztest.shape)

# hf.close()

plt.hist(ztest, len(ztest[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Test Dataset")
plt.ylabel("# samples")
plt.ylim(0,len(ztest[:,0]))
plt.tick_params(axis='y', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.xlabel("sample associated label")
# Out:
# <ipython-input-10-5479f8c08cf5>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytest = np.array(sg.get('y'+str(k)))
# <ipython-input-10-5479f8c08cf5>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# (3569, 1) (3569, 300, 1) (3569, 300, 1)
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# ## **TRAIN**

# %%
# train
history = model.fit( ytrain, ztrain, epochs=n_epochs, batch_size=batch_size, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/80
# 28/28 - 3s - loss: 0.6377 - accuracy: 0.6571 - val_loss: 0.5455 - val_accuracy: 0.7949 - lr: 0.0010 - 3s/epoch - 119ms/step
# Epoch 2/80
# 28/28 - 1s - loss: 0.4718 - accuracy: 0.8134 - val_loss: 0.4284 - val_accuracy: 0.8344 - lr: 0.0010 - 1s/epoch - 43ms/step
# Epoch 3/80
# 28/28 - 2s - loss: 0.4024 - accuracy: 0.8287 - val_loss: 0.3968 - val_accuracy: 0.8409 - lr: 0.0010 - 2s/epoch - 55ms/step
# Epoch 4/80
# 28/28 - 1s - loss: 0.4062 - accuracy: 0.8185 - val_loss: 0.3808 - val_accuracy: 0.8442 - lr: 0.0010 - 1s/epoch - 44ms/step
# Epoch 5/80
# 28/28 - 1s - loss: 0.3881 - accuracy: 0.8264 - val_loss: 0.3894 - val_accuracy: 0.8235 - lr: 0.0010 - 1s/epoch - 53ms/step
# Epoch 6/80
# 28/28 - 2s - loss: 0.3601 - accuracy: 0.8465 - val_loss: 0.3569 - val_accuracy: 0.8473 - lr: 0.0010 - 2s/epoch - 80ms/step
# Epoch 7/80
# 28/28 - 2s - loss: 0.3345 - accuracy: 0.8528 - val_loss: 0.3561 - val_accuracy: 0.8378 - lr: 0.0010 - 2s/epoch - 75ms/step
# Epoch 8/80
# 28/28 - 2s - loss: 0.3226 - accuracy: 0.8550 - val_loss: 0.3341 - val_accuracy: 0.8557 - lr: 0.0010 - 2s/epoch - 54ms/step
# Epoch 9/80
# 28/28 - 2s - loss: 0.3088 - accuracy: 0.8652 - val_loss: 0.3236 - val_accuracy: 0.8638 - lr: 0.0010 - 2s/epoch - 55ms/step
# Epoch 10/80
# 28/28 - 2s - loss: 0.3078 - accuracy: 0.8618 - val_loss: 0.3819 - val_accuracy: 0.8103 - lr: 0.0010 - 2s/epoch - 54ms/step
# Epoch 11/80
# 28/28 - 1s - loss: 0.2863 - accuracy: 0.8763 - val_loss: 0.3067 - val_accuracy: 0.8689 - lr: 0.0010 - 1s/epoch - 43ms/step
# Epoch 12/80
# 28/28 - 1s - loss: 0.2617 - accuracy: 0.8901 - val_loss: 0.3021 - val_accuracy: 0.8663 - lr: 0.0010 - 1s/epoch - 45ms/step
# Epoch 13/80
# 28/28 - 1s - loss: 0.2484 - accuracy: 0.8969 - val_loss: 0.2887 - val_accuracy: 0.8717 - lr: 0.0010 - 1s/epoch - 43ms/step
# Epoch 14/80
# 28/28 - 1s - loss: 0.2336 - accuracy: 0.9049 - val_loss: 0.2687 - val_accuracy: 0.8932 - lr: 0.0010 - 1s/epoch - 53ms/step
# Epoch 15/80
# 28/28 - 2s - loss: 0.2269 - accuracy: 0.9040 - val_loss: 0.2708 - val_accuracy: 0.8910 - lr: 0.0010 - 2s/epoch - 78ms/step
# Epoch 16/80
# 28/28 - 2s - loss: 0.2146 - accuracy: 0.9117 - val_loss: 0.2596 - val_accuracy: 0.8904 - lr: 0.0010 - 2s/epoch - 77ms/step
# Epoch 17/80
# 28/28 - 2s - loss: 0.2039 - accuracy: 0.9145 - val_loss: 0.2482 - val_accuracy: 0.9019 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 18/80
# 28/28 - 2s - loss: 0.1897 - accuracy: 0.9244 - val_loss: 0.2482 - val_accuracy: 0.9047 - lr: 0.0010 - 2s/epoch - 54ms/step
# Epoch 19/80
# 28/28 - 1s - loss: 0.1958 - accuracy: 0.9165 - val_loss: 0.2398 - val_accuracy: 0.9039 - lr: 0.0010 - 1s/epoch - 43ms/step
# Epoch 20/80
# 28/28 - 1s - loss: 0.1745 - accuracy: 0.9292 - val_loss: 0.2484 - val_accuracy: 0.8975 - lr: 0.0010 - 1s/epoch - 44ms/step
# Epoch 21/80
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 1s - loss: 0.1841 - accuracy: 0.9253 - val_loss: 0.2423 - val_accuracy: 0.9017 - lr: 0.0010 - 1s/epoch - 53ms/step
# Epoch 22/80
# 28/28 - 1s - loss: 0.1586 - accuracy: 0.9380 - val_loss: 0.2338 - val_accuracy: 0.9081 - lr: 1.0000e-04 - 1s/epoch - 44ms/step
# Epoch 23/80
# 28/28 - 2s - loss: 0.1556 - accuracy: 0.9380 - val_loss: 0.2386 - val_accuracy: 0.9050 - lr: 1.0000e-04 - 2s/epoch - 54ms/step
# Epoch 24/80
# 28/28 - 2s - loss: 0.1542 - accuracy: 0.9380 - val_loss: 0.2299 - val_accuracy: 0.9087 - lr: 1.0000e-04 - 2s/epoch - 60ms/step
# Epoch 25/80
# 28/28 - 2s - loss: 0.1554 - accuracy: 0.9340 - val_loss: 0.2297 - val_accuracy: 0.9129 - lr: 1.0000e-04 - 2s/epoch - 76ms/step
# Epoch 26/80
# 28/28 - 2s - loss: 0.1569 - accuracy: 0.9377 - val_loss: 0.2279 - val_accuracy: 0.9106 - lr: 1.0000e-04 - 2s/epoch - 77ms/step
# Epoch 27/80
# 28/28 - 1s - loss: 0.1533 - accuracy: 0.9397 - val_loss: 0.2282 - val_accuracy: 0.9095 - lr: 1.0000e-04 - 1s/epoch - 53ms/step
# Epoch 28/80
# 28/28 - 2s - loss: 0.1517 - accuracy: 0.9414 - val_loss: 0.2267 - val_accuracy: 0.9117 - lr: 1.0000e-04 - 2s/epoch - 54ms/step
# Epoch 29/80
# 28/28 - 1s - loss: 0.1522 - accuracy: 0.9377 - val_loss: 0.2269 - val_accuracy: 0.9101 - lr: 1.0000e-04 - 1s/epoch - 46ms/step
# Epoch 30/80
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 3s - loss: 0.1541 - accuracy: 0.9374 - val_loss: 0.2275 - val_accuracy: 0.9092 - lr: 1.0000e-04 - 3s/epoch - 108ms/step
# Epoch 31/80
# 28/28 - 3s - loss: 0.1490 - accuracy: 0.9388 - val_loss: 0.2270 - val_accuracy: 0.9103 - lr: 1.0000e-05 - 3s/epoch - 104ms/step
# Epoch 32/80
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 4s - loss: 0.1499 - accuracy: 0.9388 - val_loss: 0.2273 - val_accuracy: 0.9092 - lr: 1.0000e-05 - 4s/epoch - 133ms/step
# Epoch 33/80
# 28/28 - 3s - loss: 0.1492 - accuracy: 0.9414 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-06 - 3s/epoch - 125ms/step
# Epoch 34/80
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 2s - loss: 0.1501 - accuracy: 0.9377 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-06 - 2s/epoch - 58ms/step
# Epoch 35/80
# 28/28 - 1s - loss: 0.1488 - accuracy: 0.9400 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-07 - 1s/epoch - 42ms/step
# Epoch 36/80
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 2s - loss: 0.1537 - accuracy: 0.9366 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-07 - 2s/epoch - 54ms/step
# Epoch 37/80
# 28/28 - 2s - loss: 0.1491 - accuracy: 0.9411 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-08 - 2s/epoch - 54ms/step
# Epoch 38/80
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 28/28 - 2s - loss: 0.1511 - accuracy: 0.9386 - val_loss: 0.2272 - val_accuracy: 0.9101 - lr: 1.0000e-08 - 2s/epoch - 54ms/step
# Epoch 38: early stopping

# %%
# plot training history
Tloss_CNN=history.history['loss']
Vloss_CNN=history.history['val_loss']
plt.plot(Tloss_CNN,color='red')
plt.plot(Vloss_CNN,color='orange')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = model.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='red', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 1s 8ms/step
# Predict shape:
# (3569, 1)

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc

df = pd.DataFrame()
fpr = {}
tpr = {}
auc1 = {}

fpr, tpr, threshold = roc_curve(ztest,predict)

auc1 = auc(fpr, tpr)
print(type(auc1))
plt.plot(fpr,tpr, label='auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("CNN model")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')
# Out:
# <class 'numpy.float64'>

# %% [markdown]
# # **MLP Model**

# %%
#MLP
dropoutRateMLP = dropoutRate

batch_sizeMLP = batch_size
n_epochsMLP = n_epochs
n_neuronsMLP = n_neurons

####
inputList = Input(shape=(featureArrayLength))

x = Dense(n_neuronsMLP, activation='relu')(inputList[:,:,0])
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)

####
modelMLP = Model(inputs=inputList, outputs=output)

# %%
modelMLP.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
modelMLP.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 1)]          0
#
#  tf.__operators__.getitem (S  (None, 300)              0
#  licingOpLambda)
#
#  dense_2 (Dense)             (None, 258)               77658
#
#  dropout_1 (Dropout)         (None, 258)               0
#
#  dense_3 (Dense)             (None, 1)                 259
#
# =================================================================
# Total params: 77,917
# Trainable params: 77,917
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train
history = modelMLP.fit( ytrain, ztrain, epochs=n_epochsMLP, batch_size=batch_sizeMLP, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/80
# 28/28 - 1s - loss: 0.6988 - accuracy: 0.5852 - val_loss: 0.5753 - val_accuracy: 0.7467 - lr: 0.0010 - 1s/epoch - 40ms/step
# Epoch 2/80
# 28/28 - 0s - loss: 0.5371 - accuracy: 0.7528 - val_loss: 0.4860 - val_accuracy: 0.8350 - lr: 0.0010 - 237ms/epoch - 8ms/step
# Epoch 3/80
# 28/28 - 0s - loss: 0.4609 - accuracy: 0.8177 - val_loss: 0.4442 - val_accuracy: 0.8268 - lr: 0.0010 - 242ms/epoch - 9ms/step
# Epoch 4/80
# 28/28 - 0s - loss: 0.4261 - accuracy: 0.8202 - val_loss: 0.4601 - val_accuracy: 0.7694 - lr: 0.0010 - 218ms/epoch - 8ms/step
# Epoch 5/80
# 28/28 - 0s - loss: 0.4200 - accuracy: 0.8131 - val_loss: 0.4108 - val_accuracy: 0.8229 - lr: 0.0010 - 229ms/epoch - 8ms/step
# Epoch 6/80
# 28/28 - 0s - loss: 0.4006 - accuracy: 0.8168 - val_loss: 0.3958 - val_accuracy: 0.8336 - lr: 0.0010 - 226ms/epoch - 8ms/step
# Epoch 7/80
# 28/28 - 0s - loss: 0.3749 - accuracy: 0.8327 - val_loss: 0.3875 - val_accuracy: 0.8350 - lr: 0.0010 - 231ms/epoch - 8ms/step
# Epoch 8/80
# 28/28 - 0s - loss: 0.3803 - accuracy: 0.8276 - val_loss: 0.3867 - val_accuracy: 0.8249 - lr: 0.0010 - 232ms/epoch - 8ms/step
# Epoch 9/80
# 28/28 - 0s - loss: 0.3733 - accuracy: 0.8270 - val_loss: 0.3819 - val_accuracy: 0.8254 - lr: 0.0010 - 233ms/epoch - 8ms/step
# Epoch 10/80
# 28/28 - 0s - loss: 0.3675 - accuracy: 0.8352 - val_loss: 0.3813 - val_accuracy: 0.8170 - lr: 0.0010 - 323ms/epoch - 12ms/step
# Epoch 11/80
# 28/28 - 0s - loss: 0.3647 - accuracy: 0.8358 - val_loss: 0.3679 - val_accuracy: 0.8322 - lr: 0.0010 - 255ms/epoch - 9ms/step
# Epoch 12/80
# 28/28 - 0s - loss: 0.3475 - accuracy: 0.8383 - val_loss: 0.3672 - val_accuracy: 0.8271 - lr: 0.0010 - 222ms/epoch - 8ms/step
# Epoch 13/80
# 28/28 - 0s - loss: 0.3519 - accuracy: 0.8400 - val_loss: 0.3563 - val_accuracy: 0.8350 - lr: 0.0010 - 230ms/epoch - 8ms/step
# Epoch 14/80
# 28/28 - 0s - loss: 0.3357 - accuracy: 0.8494 - val_loss: 0.3475 - val_accuracy: 0.8431 - lr: 0.0010 - 226ms/epoch - 8ms/step
# Epoch 15/80
# 28/28 - 0s - loss: 0.3351 - accuracy: 0.8533 - val_loss: 0.3529 - val_accuracy: 0.8529 - lr: 0.0010 - 233ms/epoch - 8ms/step
# Epoch 16/80
# 28/28 - 0s - loss: 0.3260 - accuracy: 0.8570 - val_loss: 0.3423 - val_accuracy: 0.8386 - lr: 0.0010 - 228ms/epoch - 8ms/step
# Epoch 17/80
# 28/28 - 0s - loss: 0.3177 - accuracy: 0.8553 - val_loss: 0.3305 - val_accuracy: 0.8652 - lr: 0.0010 - 235ms/epoch - 8ms/step
# Epoch 18/80
# 28/28 - 0s - loss: 0.3072 - accuracy: 0.8700 - val_loss: 0.3263 - val_accuracy: 0.8635 - lr: 0.0010 - 228ms/epoch - 8ms/step
# Epoch 19/80
# 28/28 - 0s - loss: 0.3026 - accuracy: 0.8698 - val_loss: 0.3186 - val_accuracy: 0.8577 - lr: 0.0010 - 213ms/epoch - 8ms/step
# Epoch 20/80
# 28/28 - 0s - loss: 0.3000 - accuracy: 0.8672 - val_loss: 0.3207 - val_accuracy: 0.8532 - lr: 0.0010 - 234ms/epoch - 8ms/step
# Epoch 21/80
# 28/28 - 0s - loss: 0.2869 - accuracy: 0.8774 - val_loss: 0.3058 - val_accuracy: 0.8717 - lr: 0.0010 - 306ms/epoch - 11ms/step
# Epoch 22/80
# 28/28 - 0s - loss: 0.2845 - accuracy: 0.8760 - val_loss: 0.3010 - val_accuracy: 0.8720 - lr: 0.0010 - 220ms/epoch - 8ms/step
# Epoch 23/80
# 28/28 - 0s - loss: 0.2763 - accuracy: 0.8831 - val_loss: 0.3348 - val_accuracy: 0.8397 - lr: 0.0010 - 225ms/epoch - 8ms/step
# Epoch 24/80
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 0s - loss: 0.2930 - accuracy: 0.8771 - val_loss: 0.3340 - val_accuracy: 0.8571 - lr: 0.0010 - 235ms/epoch - 8ms/step
# Epoch 25/80
# 28/28 - 0s - loss: 0.2752 - accuracy: 0.8859 - val_loss: 0.2861 - val_accuracy: 0.8787 - lr: 1.0000e-04 - 235ms/epoch - 8ms/step
# Epoch 26/80
# 28/28 - 0s - loss: 0.2531 - accuracy: 0.8958 - val_loss: 0.2843 - val_accuracy: 0.8801 - lr: 1.0000e-04 - 256ms/epoch - 9ms/step
# Epoch 27/80
# 28/28 - 1s - loss: 0.2522 - accuracy: 0.8969 - val_loss: 0.2826 - val_accuracy: 0.8795 - lr: 1.0000e-04 - 530ms/epoch - 19ms/step
# Epoch 28/80
# 28/28 - 0s - loss: 0.2530 - accuracy: 0.8964 - val_loss: 0.2818 - val_accuracy: 0.8818 - lr: 1.0000e-04 - 268ms/epoch - 10ms/step
# Epoch 29/80
# 28/28 - 0s - loss: 0.2490 - accuracy: 0.9009 - val_loss: 0.2838 - val_accuracy: 0.8832 - lr: 1.0000e-04 - 226ms/epoch - 8ms/step
# Epoch 30/80
# 28/28 - 1s - loss: 0.2540 - accuracy: 0.8941 - val_loss: 0.2809 - val_accuracy: 0.8815 - lr: 1.0000e-04 - 663ms/epoch - 24ms/step
# Epoch 31/80
# 28/28 - 0s - loss: 0.2513 - accuracy: 0.8975 - val_loss: 0.2843 - val_accuracy: 0.8784 - lr: 1.0000e-04 - 235ms/epoch - 8ms/step
# Epoch 32/80
# 28/28 - 0s - loss: 0.2482 - accuracy: 0.8981 - val_loss: 0.2789 - val_accuracy: 0.8823 - lr: 1.0000e-04 - 228ms/epoch - 8ms/step
# Epoch 33/80
# 28/28 - 1s - loss: 0.2488 - accuracy: 0.8969 - val_loss: 0.2784 - val_accuracy: 0.8834 - lr: 1.0000e-04 - 1s/epoch - 39ms/step
# Epoch 34/80
# 28/28 - 0s - loss: 0.2499 - accuracy: 0.8961 - val_loss: 0.2783 - val_accuracy: 0.8823 - lr: 1.0000e-04 - 403ms/epoch - 14ms/step
# Epoch 35/80
# 28/28 - 0s - loss: 0.2488 - accuracy: 0.8984 - val_loss: 0.2775 - val_accuracy: 0.8834 - lr: 1.0000e-04 - 365ms/epoch - 13ms/step
# Epoch 36/80
# 28/28 - 0s - loss: 0.2476 - accuracy: 0.8972 - val_loss: 0.2810 - val_accuracy: 0.8801 - lr: 1.0000e-04 - 405ms/epoch - 14ms/step
# Epoch 37/80
# 28/28 - 0s - loss: 0.2477 - accuracy: 0.8992 - val_loss: 0.2763 - val_accuracy: 0.8826 - lr: 1.0000e-04 - 419ms/epoch - 15ms/step
# Epoch 38/80
# 28/28 - 0s - loss: 0.2455 - accuracy: 0.8989 - val_loss: 0.2769 - val_accuracy: 0.8865 - lr: 1.0000e-04 - 397ms/epoch - 14ms/step
# Epoch 39/80
# 28/28 - 0s - loss: 0.2436 - accuracy: 0.8969 - val_loss: 0.2758 - val_accuracy: 0.8837 - lr: 1.0000e-04 - 332ms/epoch - 12ms/step
# Epoch 40/80
# 28/28 - 0s - loss: 0.2412 - accuracy: 0.9006 - val_loss: 0.2748 - val_accuracy: 0.8860 - lr: 1.0000e-04 - 403ms/epoch - 14ms/step
# Epoch 41/80
# 28/28 - 0s - loss: 0.2420 - accuracy: 0.8986 - val_loss: 0.2745 - val_accuracy: 0.8848 - lr: 1.0000e-04 - 409ms/epoch - 15ms/step
# Epoch 42/80
# 28/28 - 0s - loss: 0.2422 - accuracy: 0.9012 - val_loss: 0.2736 - val_accuracy: 0.8851 - lr: 1.0000e-04 - 380ms/epoch - 14ms/step
# Epoch 43/80
# 28/28 - 0s - loss: 0.2405 - accuracy: 0.8986 - val_loss: 0.2745 - val_accuracy: 0.8857 - lr: 1.0000e-04 - 413ms/epoch - 15ms/step
# Epoch 44/80
# 28/28 - 0s - loss: 0.2413 - accuracy: 0.8975 - val_loss: 0.2721 - val_accuracy: 0.8882 - lr: 1.0000e-04 - 236ms/epoch - 8ms/step
# Epoch 45/80
# 28/28 - 0s - loss: 0.2418 - accuracy: 0.8978 - val_loss: 0.2735 - val_accuracy: 0.8860 - lr: 1.0000e-04 - 309ms/epoch - 11ms/step
# Epoch 46/80
# 28/28 - 0s - loss: 0.2390 - accuracy: 0.9006 - val_loss: 0.2708 - val_accuracy: 0.8868 - lr: 1.0000e-04 - 225ms/epoch - 8ms/step
# Epoch 47/80
# 28/28 - 0s - loss: 0.2436 - accuracy: 0.8984 - val_loss: 0.2701 - val_accuracy: 0.8888 - lr: 1.0000e-04 - 235ms/epoch - 8ms/step
# Epoch 48/80
# 28/28 - 0s - loss: 0.2395 - accuracy: 0.9026 - val_loss: 0.2752 - val_accuracy: 0.8832 - lr: 1.0000e-04 - 230ms/epoch - 8ms/step
# Epoch 49/80
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 0s - loss: 0.2413 - accuracy: 0.9006 - val_loss: 0.2771 - val_accuracy: 0.8812 - lr: 1.0000e-04 - 242ms/epoch - 9ms/step
# Epoch 50/80
# 28/28 - 0s - loss: 0.2378 - accuracy: 0.9020 - val_loss: 0.2695 - val_accuracy: 0.8882 - lr: 1.0000e-05 - 233ms/epoch - 8ms/step
# Epoch 51/80
# 28/28 - 0s - loss: 0.2372 - accuracy: 0.9018 - val_loss: 0.2689 - val_accuracy: 0.8896 - lr: 1.0000e-05 - 226ms/epoch - 8ms/step
# Epoch 52/80
# 28/28 - 0s - loss: 0.2366 - accuracy: 0.9029 - val_loss: 0.2692 - val_accuracy: 0.8896 - lr: 1.0000e-05 - 226ms/epoch - 8ms/step
# Epoch 53/80
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 0s - loss: 0.2365 - accuracy: 0.9018 - val_loss: 0.2694 - val_accuracy: 0.8882 - lr: 1.0000e-05 - 228ms/epoch - 8ms/step
# Epoch 54/80
# 28/28 - 0s - loss: 0.2374 - accuracy: 0.9037 - val_loss: 0.2694 - val_accuracy: 0.8885 - lr: 1.0000e-06 - 233ms/epoch - 8ms/step
# Epoch 55/80
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 0s - loss: 0.2342 - accuracy: 0.9040 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-06 - 219ms/epoch - 8ms/step
# Epoch 56/80
# 28/28 - 0s - loss: 0.2382 - accuracy: 0.9020 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-07 - 318ms/epoch - 11ms/step
# Epoch 57/80
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 0s - loss: 0.2386 - accuracy: 0.9032 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-07 - 236ms/epoch - 8ms/step
# Epoch 58/80
# 28/28 - 0s - loss: 0.2369 - accuracy: 0.9026 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-08 - 225ms/epoch - 8ms/step
# Epoch 59/80
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 28/28 - 0s - loss: 0.2344 - accuracy: 0.9023 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-08 - 219ms/epoch - 8ms/step
# Epoch 60/80
# 28/28 - 0s - loss: 0.2395 - accuracy: 0.9018 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-09 - 231ms/epoch - 8ms/step
# Epoch 61/80
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 28/28 - 0s - loss: 0.2328 - accuracy: 0.9052 - val_loss: 0.2694 - val_accuracy: 0.8888 - lr: 1.0000e-09 - 235ms/epoch - 8ms/step
# Epoch 61: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], color='blue', label='training MLP')
plt.plot(history.history['val_loss'], color='cyan', label='validation MLP')
plt.plot(Tloss_CNN,color='red',alpha=0.35, label='training CNN')
plt.plot(Vloss_CNN,color='orange',alpha=0.35, label='validation CNN')
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.xlabel('# Epoch')
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='upper right')
plt.show()

# %%
print("ztest shape:")
print(ztest.shape)
predict = modelMLP.predict(ytest)
print("Predict shape:")
print(predict.shape)

plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='blue', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='C0', marker='.', label='Expected label')
plt.title('Train Dataset classification')
plt.ylabel('Class index')
plt.xlim(0,len(predict[:,0]))
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
# plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 0s 2ms/step
# Predict shape:
# (3569, 1)

# %%
plt.plot(fpr,tpr, label='CNN: auc='+str(np.round(auc1*100,2))+'% , # neurons='+str(n_neurons), color='red',alpha=0.35)

df = pd.DataFrame()
fprMLP = {}
tprMLP = {}
auc1MLP = {}

fprMLP, tprMLP, thresholdMLP = roc_curve(ztest,predict)

auc1MLP = auc(fprMLP, tprMLP)

plt.plot(fprMLP,tprMLP, label='MLP: auc='+str(np.round(auc1MLP*100,2))+'% , # neurons='+str(n_neuronsMLP), color='blue')

plt.semilogy()
plt.ylim(0.000001,1)
plt.title("ROC curve")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.minorticks_on()
plt.tick_params(axis='x', which='both', direction='out')
plt.grid(which='major', color='#CCCCCC', linestyle='--')
plt.grid(which='minor', color='#CCCCCC', linestyle=':')
plt.legend(loc='lower right')

print('*****Summary of Hyperparameters**')
print('Drop Out CNN:', dropoutRate)
print('# neurons CNN:', n_neurons)
print('batch size CNN:', batch_size)
print('*****')
print('Drop Out MLP:', dropoutRateMLP)
print('# neurons MLP:', n_neuronsMLP)
print('batch size MLP:', batch_sizeMLP)
# Out:
# *****Summary of Hyperparameters**
# Drop Out CNN: 0.25
# # neurons CNN: 258
# batch size CNN: 128
# *****
# Drop Out MLP: 0.25
# # neurons MLP: 258
# batch size MLP: 128

# %% [markdown]
# # **DISCUSSION OF RESULTS**
#
# 1.   **Dataset choise**
#
# To reach our binary classification task, 2 different pairs of dataset (2 for the *train* task and 2 for the *test* task) have been produced. The first train dataset is more unbalanced in the 2 class,
#
# 2.   ****

# %%
import numpy as np
import matplotlib.pyplot as plt

N_neurons=[4,8,32,128,258]
Nb_parCNN=[12009,23937,95505,381777,769437]
Nb_parMLP=[1209,2417,9665,38657,77917]
Auc_CNN=[93.15,93.18,92.08,96.65,96.93]
Auc_MLP=[50.76,90.06,91.09,91.41,95.79]
Lt_CNN=[0.4,0.4,0.39,0.14,0.15]
Lt_MLP=[0.69,0.42,0.37,0.36,0.23]
Lv_CNN=[0.36,0.36,0.36,0.24,0.23]
Lv_MLP=[0.69,0.41,0.38,0.37,0.27]
Nb_parCNN=np.array(Nb_parCNN)/1000
Nb_parMLP=np.array(Nb_parMLP)/1000

CNN2=[32,48665/1000,0.18,0.23,93.72]
CNN3=[16,13653/1000,0.13,0.23,97.32]

fig, (ax1,ax2) = plt.subplots(figsize=(10,4), nrows=1, ncols=2, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(50,100)
  # ax.set_xlim(0,1)
  ax.set_ylabel('Accuracy (%)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

plt.suptitle('CNN vs MLP')

ax1.plot(N_neurons,Auc_CNN,color='red',marker='o')
ax1.plot(N_neurons,Auc_MLP,color='blue',marker='o')
ax1.scatter(32,93.72,color='crimson',marker='x')
ax1.scatter(16,97.32,color='crimson',marker='*')
ax1.set_xlabel('# neurons')
ax2.plot(Nb_parCNN,Auc_CNN,color='red',marker='o', label='CNN 1')
ax2.plot(Nb_parMLP,Auc_MLP,color='blue',marker='o', label='MLP')
ax2.scatter(48665/1000,93.72,color='crimson',marker='x', label='CNN 2')
ax2.scatter(13653/1000,97.32,color='crimson',marker='*',label='CNN 3')
ax2.set_xlabel('#k parameters')


ax2.legend()
plt.show()

fig, (ax1,ax2) = plt.subplots(figsize=(10,4), nrows=1, ncols=2, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(0,1)
  # ax.set_xlim(0,1)
  ax.set_ylabel('Loss')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

plt.suptitle('CNN vs MLP')

ax1.plot(N_neurons,Lt_CNN,color='red',marker='o')
ax1.plot(N_neurons,Lv_CNN,color='orange',marker='s')
ax1.plot(N_neurons,Lt_MLP,color='blue',marker='o')
ax1.plot(N_neurons,Lv_MLP,color='cyan',marker='s')
ax1.set_xlabel('# neurons')
ax2.plot(Nb_parCNN,Lt_CNN,color='red',marker='o', label='CNN 1 - test')
ax2.plot(Nb_parCNN,Lv_CNN,color='orange',marker='s', label='CNN 1 - validation')
ax2.plot(Nb_parMLP,Lt_MLP,color='blue',marker='o', label='MLP - test')
ax2.plot(Nb_parMLP,Lv_MLP,color='cyan',marker='s', label='MLP - validation')
ax2.set_xlabel('#k parameters')

ax2.legend()
plt.show()
