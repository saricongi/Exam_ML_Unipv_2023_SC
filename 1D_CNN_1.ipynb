# %% [markdown]
# <a href="https://colab.research.google.com/github/saricongi/Exam_ML_Unipv_2023_SC/blob/master/1D_CNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.sparse import load_npz
import h5py

# %%
# directory = 'https://github.com/saricongi/Project_ML_Unipv_23.git'
# !git clone https://github.com/saricongi/Project_ML_Unipv_23.git
# !curl https://github.com/saricongi/Project_ML_Unipv_23.git
# Out:
# Cloning into 'Project_ML_Unipv_23'...
# fatal: could not read Username for 'https://github.com': No such device or address
# <html>
# <head><title>301 Moved Permanently</title></head>
# <body>
# <center><h1>301 Moved Permanently</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %% [markdown]
# The dataset is made by transmission optical spectra of optical resonators integrated on a silicon chip as the one shown here:
# <div>
# <img src="https://github.com/saricongi/Project_ML_Unipv_23/blob/main/device.png?raw=1" width="800"/>
# </div>
#
# A typical mesured spectrum can have a shape as the following:
# <div>
# <img src="https://github.com/saricongi/Project_ML_Unipv_23/blob/main/Example.png?raw=1" width="600"/>
# </div>
#
# The analysis of this type of spectra with theoretical models is not straightforward, because one single resonance is given by the contribution of both ring resonators, with interference occuring between the two. For application in light storing and optical switchers, we are interested on the devices and wavelength ranges where double peaks occurs.
#
# The goal of this ML project is to correctly recognize if a resonance is showing the  single-peak or the double-peak behaviour. Therefore, each spectrum has a label *z* to classify it into the two possible groups (*binary classification problem*).
#
# Since it is a periodic pattern, the full wavelength (*wl*) scan has been splitted in different arrays of equal length (*300*), each of them contains a single resonance. In this way, more than 6000 resonance spectra have been recorded, divided in *train* and *test* datasets.
#
# Moreovere, the information on the absolute wl is not of our interest, thus we are going to normalize it (*x* between 0 and 1). Since independetly on the resonance position we want to be able to classifie the peaks, our problem exibits translational symmetry. For this reason, the model implemented is a *1D CNN*.
#
#
# **DATASETs STRUCTURE:**
#
# * **Train dataset = 3532 spectra**
# * **Test (or evaluation) dataset = 3569 spectra**
# * **1 spectrum = 300 wavelength points -> y**.
# * **Nb labels = 2 -> z**, *z=0* if there is only one visible peak, *z=1* if the resonance is splittend into 2 peaks.

# %% [markdown]
# **Visualisation of Train Dataset:**

# %%
## Train DataSet
url = '/content/Project_ML_Unipv_23/DataSet.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=0
j=24
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=2
j=30
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=3
j=35
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-24c1cb0b3cba> in <cell line: 25>()
#      23 ResNb2=20
#      24
# ---> 25 hf = h5py.File(url)
#      26 print(hf.keys())
#      27 g = hf.get(Group)
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     565                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                                  fs_page_size=fs_page_size)
# --> 567                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568
#     569             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229         if swmr and swmr_support:
#     230             flags |= h5f.ACC_SWMR_READ
# --> 231         fid = h5f.open(name, flags, fapl=fapl)
#     232     elif mode == 'r+':
#     233         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/content/Project_ML_Unipv_23/DataSet.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(0,NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytrain = []
xtrain = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytrain = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytrain.append(my_ytrain)
      target.append(my_target)
      xtrain.append(x)

ytrain=np.array(ytrain).reshape(-1,300,1)
ztrain=np.array(target).reshape(-1,1)
xtrain=np.array(xtrain).reshape(-1,300,1)

print("xtrain shape: ", xtrain.shape)
print("ytrain shape: ", ytrain.shape)
print("ztrain shape: ", ztrain.shape)

hf.close()
# Out:
# <ipython-input-4-5c7621e0802b>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytrain = np.array(sg.get('y'+str(k)))
# <ipython-input-4-5c7621e0802b>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# xtrain shape:  (3532, 300, 1)
# ytrain shape:  (3532, 300, 1)
# ztrain shape:  (3532, 1)

# %% [markdown]
# Let's check that in the train dataset there the two labels are well distributed:

# %%
plt.hist(ztrain, len(ztrain[:,0]), density=True, histtype='step', fill=True, linewidth=1.5)
plt.title("Train Dataset")
plt.ylabel("# samples")
plt.xlabel("sample associated label")
# Out:
# Text(0.5, 0, 'sample associated label')

# %% [markdown]
# **1D CNN MODEL**

# %%
# keras imports
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Conv1D, AveragePooling1D, Dropout, Flatten
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN

# %%
featureArrayLength = (ytrain.shape[1],ytrain.shape[2])
dropoutRate = 0.25

# %%
batch_size = 128
n_epochs = 50
n_neurons = 16

####
inputList = Input(shape=(featureArrayLength))
x = Conv1D(20, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(inputList)
x = AveragePooling1D(pool_size=2)(x)
#
x = Conv1D(40, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=4)(x)
#
x = Conv1D(60, kernel_size=3, data_format="channels_last", strides=1, padding="valid", activation='relu')(x)
x = AveragePooling1D(pool_size=8)(x)
#
x = Flatten()(x)
x = Dense(n_neurons, activation='relu')(x)
x = Dropout(dropoutRate)(x)
output = Dense(1, activation='sigmoid')(x)
####
model = Model(inputs=inputList, outputs=output)

# %%
# from tensorflow.keras.losses import BinaryCrossentropy
# model.compile(loss=BinaryCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(inputList)
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 300, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 1)]          0
#
#  conv1d (Conv1D)             (None, 298, 20)           80
#
#  average_pooling1d (AverageP  (None, 149, 20)          0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 147, 40)           2440
#
#  average_pooling1d_1 (Averag  (None, 36, 40)           0
#  ePooling1D)
#
#  conv1d_2 (Conv1D)           (None, 34, 60)            7260
#
#  average_pooling1d_2 (Averag  (None, 4, 60)            0
#  ePooling1D)
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 16)                3856
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13,653
# Trainable params: 13,653
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Test Dataset**

# %%
## Test DataSet

url = '/content/Project_ML_Unipv_23/DataSet_test.h5'

fig, (ax1,ax2,ax3) = plt.subplots(figsize=(15,4), nrows=1, ncols=3, tight_layout=True)
for ax in fig.get_axes():
  ax.minorticks_on()
  ax.tick_params(axis='x', which='both', direction='out')
  ax.grid(which='major', color='#CCCCCC', linestyle='--')
  ax.grid(which='minor', color='#CCCCCC', linestyle=':')
  ax.set_ylim(-0.05,1.1)
  ax.set_xlim(0,1)
  ax.set_xlabel('Normalized wavelength (a.u.)')
  ax.set_ylabel('Optical transmission (a.u.)')
  ax.label_outer()
plt.subplots_adjust(hspace=0.3, wspace=0.3)

#plot 1
i=4
j=26
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=2
ResNb2=21

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())


x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))
l=len(x1)
print('\n Length of x and y arrays:', l, '\n')
x=np.linspace(0,1,l) #normalized x-array

ax1.set_title(Group+' - '+Subgroup)
ax1.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax1.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax1.legend()

#plot 2
i=6
j=32
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax2.set_title(Group+' - '+Subgroup)
ax2.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax2.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax2.legend()

#plot 3
i=7
j=40
Group='Die'+str(i)
Subgroup='Subdie'+str(j)
ResNb=1
ResNb2=20

hf = h5py.File(url)
print(hf.keys())
g = hf.get(Group)
print(g.keys())
sg = g.get(Subgroup)
print(sg.keys())

x1 = sg.get('x'+str(ResNb))
print(x1)
x1=np.array(x1)
y1 = np.array(sg.get('y'+str(ResNb)))
z1 = np.array(sg.get('z'+str(ResNb)))

ax3.set_title(Group+' - '+Subgroup)
ax3.plot(x,y1, label='Res #'+str(ResNb)+', label='+str(z1))

x1 = np.array(sg.get('x'+str(ResNb2)))
y1 = np.array(sg.get('y'+str(ResNb2)))
z1 = np.array(sg.get('z'+str(ResNb2)))

ax3.plot(x,y1, label='Res #'+str(ResNb2)+', label='+str(z1))
ax3.legend()
# Out:
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x2": shape (300,), type "<f8">
#
#  Length of x and y arrays: 300
#
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <KeysViewHDF5 ['Die4', 'Die5', 'Die6', 'Die7']>
# <KeysViewHDF5 ['Subdie24', 'Subdie25', 'Subdie26', 'Subdie27', 'Subdie28', 'Subdie29', 'Subdie30', 'Subdie31', 'Subdie32', 'Subdie33', 'Subdie34', 'Subdie35', 'Subdie36', 'Subdie37', 'Subdie38', 'Subdie39', 'Subdie40', 'Subdie41', 'Subdie42', 'Subdie43', 'Subdie44', 'Subdie45']>
# <KeysViewHDF5 ['x1', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x2', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x3', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x4', 'x40', 'x41', 'x42', 'x43', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y2', 'y20', 'y21', 'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y3', 'y30', 'y31', 'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y4', 'y40', 'y41', 'y42', 'y43', 'y5', 'y6', 'y7', 'y8', 'y9', 'z1', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z2', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'z29', 'z3', 'z30', 'z31', 'z32', 'z33', 'z34', 'z35', 'z36', 'z37', 'z38', 'z39', 'z4', 'z40', 'z41', 'z42', 'z43', 'z5', 'z6', 'z7', 'z8', 'z9']>
# <HDF5 dataset "x1": shape (300,), type "<f8">
# <ipython-input-10-09ca68846b74>:36: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-10-09ca68846b74>:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:38: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:46: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:47: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:48: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:70: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-10-09ca68846b74>:71: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:72: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:77: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:78: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:79: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:101: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1=np.array(x1)
# <ipython-input-10-09ca68846b74>:102: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:103: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb)))
# <ipython-input-10-09ca68846b74>:108: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   x1 = np.array(sg.get('x'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:109: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   y1 = np.array(sg.get('y'+str(ResNb2)))
# <ipython-input-10-09ca68846b74>:110: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   z1 = np.array(sg.get('z'+str(ResNb2)))

# %% [markdown]
# **Geneting the arrays suitable for keras ML algorithms**

# %%
NbDies=4
NbSubDies=45
DIES = np.linspace(4,4+NbDies-1,NbDies,dtype=int)
SUBDIES = np.linspace(24,NbSubDies-1,NbSubDies-24,dtype=int)

target = []
ytest = []
xtest = []

for i in (DIES):
  Group='Die'+str(i)
  # print('Die',i)

  for j in (SUBDIES):
    Subgroup='Subdie'+str(j)
    # print('Subdie',j)
    g = hf.get(Group)
    sg = g.get(Subgroup)
    # print(sg.keys())
    NbRes=int(len(sg.keys())/3)
    # print('Total # of reosonances=', NbRes)

    for k in range(NbRes):
      k=k+1
      # print('k=',k)
      my_ytest = np.array(sg.get('y'+str(k)))
      my_target = np.array(sg.get('z'+str(k)))
      # print('z',k,'=',my_target)
      ytest.append(my_ytest)
      target.append(my_target)
      xtest.append(x)

ytest=np.array(ytest).reshape(-1,300,1)
ztest=np.array(target).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,300,1)
print(ztest.shape, ytest.shape, xtest.shape)

# ztest = to_categorical(target, num_classes = 2)
# print("New dimension of test target:")
# print(ztest.shape)

hf.close()
# Out:
# <ipython-input-11-ae1c339cc940>:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_ytest = np.array(sg.get('y'+str(k)))
# <ipython-input-11-ae1c339cc940>:27: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_target = np.array(sg.get('z'+str(k)))
# (3569, 1) (3569, 300, 1) (3569, 300, 1)

# %%
# train
history = model.fit( ytrain, ztrain, epochs=n_epochs, batch_size=batch_size, verbose = 2,
                validation_data=(ytest, ztest),
                callbacks = [
                EarlyStopping(monitor='val_loss', patience=10, verbose=1),
                ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                TerminateOnNaN()] )
# Out:
# Epoch 1/50
# 28/28 - 5s - loss: 0.6915 - accuracy: 0.5340 - val_loss: 0.6948 - val_accuracy: 0.4937 - lr: 0.0010 - 5s/epoch - 182ms/step
# Epoch 2/50
# 28/28 - 2s - loss: 0.6877 - accuracy: 0.5433 - val_loss: 0.6955 - val_accuracy: 0.4937 - lr: 0.0010 - 2s/epoch - 63ms/step
# Epoch 3/50
# 28/28 - 2s - loss: 0.6810 - accuracy: 0.5470 - val_loss: 0.6815 - val_accuracy: 0.4943 - lr: 0.0010 - 2s/epoch - 60ms/step
# Epoch 4/50
# 28/28 - 2s - loss: 0.6480 - accuracy: 0.6237 - val_loss: 0.6243 - val_accuracy: 0.6974 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 5/50
# 28/28 - 2s - loss: 0.5455 - accuracy: 0.7593 - val_loss: 0.4911 - val_accuracy: 0.8465 - lr: 0.0010 - 2s/epoch - 60ms/step
# Epoch 6/50
# 28/28 - 2s - loss: 0.4088 - accuracy: 0.8256 - val_loss: 0.3832 - val_accuracy: 0.8731 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 7/50
# 28/28 - 3s - loss: 0.3265 - accuracy: 0.8601 - val_loss: 0.3464 - val_accuracy: 0.8725 - lr: 0.0010 - 3s/epoch - 95ms/step
# Epoch 8/50
# 28/28 - 3s - loss: 0.2785 - accuracy: 0.8913 - val_loss: 0.3855 - val_accuracy: 0.8406 - lr: 0.0010 - 3s/epoch - 91ms/step
# Epoch 9/50
# 28/28 - 2s - loss: 0.2759 - accuracy: 0.9009 - val_loss: 0.2838 - val_accuracy: 0.9109 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 10/50
# 28/28 - 2s - loss: 0.2540 - accuracy: 0.9097 - val_loss: 0.2802 - val_accuracy: 0.9157 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 11/50
# 28/28 - 2s - loss: 0.2303 - accuracy: 0.9230 - val_loss: 0.2664 - val_accuracy: 0.9199 - lr: 0.0010 - 2s/epoch - 60ms/step
# Epoch 12/50
# 28/28 - 2s - loss: 0.2104 - accuracy: 0.9386 - val_loss: 0.2725 - val_accuracy: 0.9157 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 13/50
# 28/28 - 2s - loss: 0.2021 - accuracy: 0.9388 - val_loss: 0.2462 - val_accuracy: 0.9336 - lr: 0.0010 - 2s/epoch - 63ms/step
# Epoch 14/50
# 28/28 - 3s - loss: 0.1933 - accuracy: 0.9468 - val_loss: 0.2427 - val_accuracy: 0.9370 - lr: 0.0010 - 3s/epoch - 92ms/step
# Epoch 15/50
# 28/28 - 3s - loss: 0.1961 - accuracy: 0.9405 - val_loss: 0.2379 - val_accuracy: 0.9375 - lr: 0.0010 - 3s/epoch - 113ms/step
# Epoch 16/50
# 28/28 - 2s - loss: 0.1944 - accuracy: 0.9442 - val_loss: 0.2516 - val_accuracy: 0.9344 - lr: 0.0010 - 2s/epoch - 61ms/step
# Epoch 17/50
# 28/28 - 2s - loss: 0.1859 - accuracy: 0.9536 - val_loss: 0.2374 - val_accuracy: 0.9370 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 18/50
# 28/28 - 2s - loss: 0.1761 - accuracy: 0.9581 - val_loss: 0.2471 - val_accuracy: 0.9358 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 19/50
# 28/28 - 2s - loss: 0.1755 - accuracy: 0.9575 - val_loss: 0.2327 - val_accuracy: 0.9428 - lr: 0.0010 - 2s/epoch - 62ms/step
# Epoch 20/50
# 28/28 - 2s - loss: 0.1742 - accuracy: 0.9558 - val_loss: 0.2348 - val_accuracy: 0.9451 - lr: 0.0010 - 2s/epoch - 55ms/step
# Epoch 21/50
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 28/28 - 2s - loss: 0.1716 - accuracy: 0.9572 - val_loss: 0.2787 - val_accuracy: 0.9235 - lr: 0.0010 - 2s/epoch - 85ms/step
# Epoch 22/50
# 28/28 - 3s - loss: 0.1693 - accuracy: 0.9604 - val_loss: 0.2365 - val_accuracy: 0.9445 - lr: 1.0000e-04 - 3s/epoch - 115ms/step
# Epoch 23/50
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 28/28 - 2s - loss: 0.1593 - accuracy: 0.9612 - val_loss: 0.2466 - val_accuracy: 0.9398 - lr: 1.0000e-04 - 2s/epoch - 63ms/step
# Epoch 24/50
# 28/28 - 2s - loss: 0.1643 - accuracy: 0.9618 - val_loss: 0.2411 - val_accuracy: 0.9420 - lr: 1.0000e-05 - 2s/epoch - 59ms/step
# Epoch 25/50
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 28/28 - 2s - loss: 0.1600 - accuracy: 0.9635 - val_loss: 0.2384 - val_accuracy: 0.9437 - lr: 1.0000e-05 - 2s/epoch - 64ms/step
# Epoch 26/50
# 28/28 - 2s - loss: 0.1607 - accuracy: 0.9623 - val_loss: 0.2382 - val_accuracy: 0.9437 - lr: 1.0000e-06 - 2s/epoch - 63ms/step
# Epoch 27/50
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 28/28 - 2s - loss: 0.1558 - accuracy: 0.9626 - val_loss: 0.2382 - val_accuracy: 0.9437 - lr: 1.0000e-06 - 2s/epoch - 66ms/step
# Epoch 28/50
# 28/28 - 3s - loss: 0.1611 - accuracy: 0.9638 - val_loss: 0.2382 - val_accuracy: 0.9440 - lr: 1.0000e-07 - 3s/epoch - 91ms/step
# Epoch 29/50
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 28/28 - 3s - loss: 0.1556 - accuracy: 0.9657 - val_loss: 0.2381 - val_accuracy: 0.9440 - lr: 1.0000e-07 - 3s/epoch - 99ms/step
# Epoch 29: early stopping

# %%
# plot training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.yscale('log')
plt.title('Training History')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
labels = ['single peak', 'double peak']

print("ztest shape:")
print(ztest.shape)
predict = model.predict(ytest)
print("Predict shape:")
print(predict.shape)

# plt.hist(ztest, len(ztest[:,0]), color='blue', density=True, histtype='step', fill=True, linewidth=1.5)
# plt.hist(predict, len(predict[:,0]), color='red',  density=True, histtype='step', fill=True, linewidth=1.5)
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), predict[:,0], color='red', marker='.', label='Predict label')
plt.scatter(np.linspace(1,len(predict[:,0]),len(predict[:,0])), ztest[:,0], color='blue', marker='.', label='Expected label')
plt.title('Classification')
plt.ylabel('Class index')
plt.xlabel('Sample #')
plt.legend()
# Out:
# ztest shape:
# (3569, 1)
# 112/112 [==============================] - 1s 10ms/step
# Predict shape:
# (3569, 1)

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc

df = pd.DataFrame()
fpr = {}
tpr = {}
auc1 = {}

plt.figure()

fpr, tpr, threshold = roc_curve(ztest,predict)

auc1 = auc(fpr, tpr)
print(type(auc1))
plt.plot(fpr,tpr, label='auc = '+str(np.round(auc1*100,2))+'%')

plt.semilogy()
plt.ylim(0.000001,1)
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.grid(True)
plt.legend(loc='lower right')
plt.show()
# Out:
# <class 'numpy.float64'>
